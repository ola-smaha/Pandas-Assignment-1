# %% [markdown]
# # Part 1

# %% [markdown]
# Importing pandas:

# %%
import pandas as pd

# %% [markdown]
# Reading and importing data:

# %%
df = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# ## 1. Viewing and explaining variables

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1010000.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
df['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %% [markdown]
# So, we're assuming that the **view** variable takes 5 values rating the view from 0 to 5, 5 being the highest.

# %% [markdown]
# ### Variable reference:

# %% [markdown]
# **id**: An identifier for each sale <br>
# **date**: The date when the house was sold <br>
# **price**: The price of the house <br>
# **bedrooms**: The number of bedrooms in each house <br>
# **bathrooms**: The number of bathrooms in each house where 0.5 accounts for a bathroom attached to a room but without all the items (toilet, shower..)<br>
# **sqft_living**: The living area of the house (apartment space) in square feet<br>
# **sqft_lot**: The total area of the house in square feet<br>
# **floors**: The number of floors <br>
# **waterfront**: A variable indicating whether the house has a waterfront view; 0 if it doesn't, 1 if it does<br>
# **view**: A variable that takes the values from 0 to 4 representing how good the view is<br>
# **condition**: An variable that takes the values from 1 to 5 representing the condition of the house<br>
# **grade**: An variable that takes the values from 1 to 13 representing the grade given to the house<br>
# **sqft_above**: How many square feet the house is above the ground level (so excluding basements and underground areas)<br>
# **sqft_basement**: The square footage of the house's basement<br>
# **yr_built**: The year the house was built<br>
# **yr_renovated**: The year the house was renovated last<br>
# **zipcode**: The area zipcode where the house is in<br>
# **lat**: The latitude of the house's location<br>
# **long**: The longitude of the house's location<br><br>
# *Side note: Latitude and longitude are parameters or coordinates that help determine the location of any place on Earth. Both latitude and longitude are angles that uniquely define points on the Earth's sphere. They constitute a coordinate system or scheme to locate or identify geographic positions anywhere on the Earth's surface.*<br>
# *Source: https://www.techtarget.com/whatis/definition/latitude-and-longitude#:~:text=Latitudes%20are%20horizontal%20lines%20that,or%20places%20on%20the%20globe.*<br><br>
# **sqft_living15**: The average square footage of the living space of the nearest 15 neighbors<br>
# **sqft_lot15**: The average square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# ## 2. Variable Specificities and Distribution

# %% [markdown]
# ### Variable Types:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# **Note**: The 64 in int64 refers to the memory allocated to hold this character. It represents signed integers with values that range from negative 9,223,372,036,854,775,808 through positive 9,223,372,036,854,775,807.

# %% [markdown]
# **Nominal Categorical**: id, zipcode *(as there is no order, and the numbers are unqiue identifiers)*<br>
# **Binary Categorical**: waterfront<br>
# **Ordinal Categorical**: view, condition, grade, date *(There is an order or ranking)*<br>
# **Numerical (Continuous)**: price, sqft_living, sqft_lot, lat, long<br>
# **Numerical (Discrete)**: bedrooms, bathrooms, floors, sqft_above, sqft_basement, yr_built, yr_renovated, sqft_living15, sqft_lot15<br>
# *Note: We considered 'bathrooms' to be discrete, even though it takes decimal values, and that's assuming it only takes .25, .5, .75*<br>
# *Same goes for floors, assuming there are attics in some houses, thus the .5*

# %% [markdown]
# Note that some variables are not regarded as numerical even though their Dtype is int64 (example: view).

# %% [markdown]
# ### Common values

# %% [markdown]
# One way to find the number of occurences of a value is using the method ```value_counts()```:

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Most observed number of floors:
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# The decimal part is explained in the above section.

# %%
df.waterfront.value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %% [markdown]
# #### Some insights:

# %%
no_water_view = df[df['waterfront'] == 0]
water_view = df[df['waterfront'] == 1]

# %%
print(water_view['price'].mean().round(2),no_water_view['price'].mean().round(2))
# Out:
# 1662524.18 531653.41

# %% [markdown]
# The average price of the houses with no waterfront view (531,653.41) is much smaller than that of houses with waterfront view (1,662,524.18). This potentially indicates a correlation between the two variables 'waterfront' and 'view'.

# %% [markdown]
# ### Max and Min values:

# %% [markdown]
# Let's check the maximum and minimum values of some of our variables:

# %%
df['bedrooms'].max()
# Out:
# 33

# %%
df[df['bedrooms']==33]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15870 -122.331           1330        4700
#
# [1 rows x 21 columns]

# %% [markdown]
# A house with 33 bedrooms has 1 bathroom other than the one exclusive to one of the bedrooms, something seems off...

# %%
df.nlargest(5,'price')
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7060000.0         5       4.50
# 9254  9208900037  20140919T000000  6890000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# The priciest house has 6 bedrooms, much less than 33. It has more bathrooms, a bigger area, a better view, and is graded higher. This could mean that there was a mistake while recording the data, that entry might be considered an outlier.

# %%
df.nsmallest(10,'sqft_living')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 19452  3980300371  20140926T000000  142000.0         0       0.00
# 15381  2856101479  20140701T000000  276000.0         1       0.75
# 860    1723049033  20140620T000000  245000.0         1       0.75
# 18379  1222029077  20141029T000000  265000.0         0       0.75
# 4868   6896300380  20141002T000000  228000.0         0       1.00
# 21332  9266700190  20150511T000000  245000.0         1       1.00
# 8623   6303400395  20150130T000000  325000.0         1       0.75
# 11500  4322200105  20150331T000000  229050.0         1       1.00
# 14466  7549801385  20140612T000000  280000.0         1       0.75
# 465    8658300340  20140523T000000   80000.0         1       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19452          290     20875     1.0           0     0  ...      1
# 15381          370      1801     1.0           0     0  ...      5
# ...

# %% [markdown]
# If we look at the price, sqft_living, and the sqft_lot variables, we could notice some kind of relation between the three. So, one might affect the other; could be worth looking into and drawing the conclusion that generally, the bigger the property, the pricier it is.

# %% [markdown]
# ## 3.  Time, Latitude, and Longitude

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
top_prices = df.nlargest(30,'price')
top_prices[['date','lat','long','price','grade','sqft_lot']]
# Out:
#                   date      lat     long      price  grade  sqft_lot
# 7252   20141013T000000  47.6298 -122.323  7700000.0     13     27600
# 3914   20140611T000000  47.6500 -122.214  7060000.0     11     37325
# 9254   20140919T000000  47.6305 -122.240  6890000.0     13     31374
# 4411   20140804T000000  47.6289 -122.233  5570000.0     13     35069
# 1448   20150413T000000  47.6232 -122.220  5350000.0     12     23985
# 1315   20150413T000000  47.5631 -122.210  5300000.0     12     24829
# 1164   20141020T000000  47.6767 -122.211  5110000.0     12     45517
# 8092   20140617T000000  47.5570 -122.210  4670000.0     12     13068
# 2626   20140815T000000  47.7493 -122.280  4500000.0     12     40014
# 8638   20140618T000000  47.6208 -122.219  4490000.0     12     27517
# 12370  20150506T000000  47.5692 -122.189  4210000.0     12     21540
# 4149   20141014T000000  47.6151 -122.224  4000000.0     12     16573
# 2085   20141114T000000  47.5850 -122.222  3850000.0     11     21300
# ...

# %% [markdown]
# It seems a bit difficult to spot a relation between the date and prices, further analysis should be performed, by plotting the median sale price over time for example. As for the latitude and longitude, I'm not sure what to conclude based on the numbers, as they seem close to each other, generally.

# %% [markdown]
# # Part 2

# %% [markdown]
# ### .head()

# %% [markdown]
# This function returns the first n rows for the object based on position. It is useful for quickly testing if our object has the right type of data in it.

# %%
# For negative values of n, this function returns all rows except the last |n| rows, equivalent to df[:n]
df.head(-21608)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# If n is larger than the number of rows, this function returns all rows
df.head(22000)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# **Parameters**:<br>
# ```
# n: int, default: 5 <br>
# n is the number of rows to select
# ```

# %% [markdown]
# ### .tail()

# %% [markdown]
# This function returns last n rows from the object based on position. It is useful for quickly verifying data, for example, after sorting or appending rows.

# %%
# For negative values of n, this function returns all rows except the first |n| rows, equivalent to df[|n|:]
df.tail(-21610)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21610 -122.299           1020        2007
# ...

# %%
# If n is larger than the number of rows, this function returns all rows
df.tail(23000)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# **Parameters:**<br>
# ```
# n: int, default: 5
# n is the number of rows to select.
# ```

# %% [markdown]
# ### .option_context(*args)

# %% [markdown]
# Context manager to temporarily set options in the with statement context.<br>
# You need to invoke as option_context(pat, val, [(pat, val), ...]).<br><br>
# Examples:

# %%
with pd.option_context('display.max_rows',6,'display.max_columns',10):
    display(df)
# display.maxrows and display.max_columns control the maximum number of rows and columns displayed when printing a DataFrame, respectively
# Out:
#                id             date     price  bedrooms  bathrooms  ...  \
# 0      7129300520  20141013T000000  221900.0         3       1.00  ...
# 1      6414100192  20141209T000000  538000.0         3       2.25  ...
# 2      5631500400  20150225T000000  180000.0         2       1.00  ...
# ...           ...              ...       ...       ...        ...  ...
# 21610  1523300141  20140623T000000  402101.0         2       0.75  ...
# 21611   291310100  20150116T000000  400000.0         3       2.50  ...
# 21612  1523300157  20141015T000000  325000.0         2       0.75  ...
#
#        zipcode      lat     long  sqft_living15  sqft_lot15
# 0        98178  47.5112 -122.257           1340        5650
# 1        98125  47.7210 -122.319           1690        7639
# 2        98028  47.7379 -122.233           2720        8062
# ...        ...      ...      ...            ...         ...
# 21610    98144  47.5944 -122.299           1020        2007
# ...

# %% [markdown]
# There are other arguments we could use like display.max_colwidth (Sets the maximum width of each column when printing DataFrames).

# %% [markdown]
# ```
# Note: The with statement is used to work with context managers. It provides a concise and readable way to interact with resources or configurations that require specific actions to be taken before and after a block of code is executed.
# ```

# %% [markdown]
# ### .columns

# %% [markdown]
# It returns the column labels of the DataFrame.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ### .shape

# %% [markdown]
# Return a tuple representing the dimensionality of the DataFrame.

# %%
df.shape
# Output: (rows,columns)
# Out:
# (21613, 21)

# %% [markdown]
# ### .info

# %% [markdown]
# ```DataFrame.info(verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None)```<br>
# Print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
#
# **Parameters:**
# verbose: bool, optional<br>
# buf: writable buffer, defaults to sys.stdout<br>
# max_cols: int, optional<br>
# memory_usage: bool, str, optional<br>
# show_counts: bool, optional<br>

# %% [markdown]
# Examples:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Columns: 21 entries, id to sqft_lot15
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ### .column_name and ['column name']

# %% [markdown]
# df.price and df['price'] return the same result
# ```
# But what about df[['price']] and df['price']?
# ```

# %%
prices1 = df['price']
prices2 = df[['price']]

# %%
type(prices1)
# Out:
# pandas.core.series.Series

# %%
type(prices2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# As we can see, the first returns a series, the second returns a DataFrame (This serves as a solution for the exercise mentioned in session). This might be useful if we need to work on a specific column using DataFrame methods.

# %%
df[df.bathrooms == 0.0]
# This returns all entries where there are no bathrooms.
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 875    6306400140  20140612T000000  1100000.0         0        0.0
# 1149   3421079032  20150217T000000    75000.0         1        0.0
# 3119   3918400017  20150205T000000   380000.0         0        0.0
# 5832   5702500050  20141104T000000   280000.0         1        0.0
# 6994   2954400190  20140624T000000  1300000.0         0        0.0
# 9773   3374500520  20150429T000000   355000.0         0        0.0
# 9854   7849202190  20141223T000000   235000.0         0        0.0
# 10481   203100435  20140918T000000   484000.0         1        0.0
# 14423  9543000205  20150413T000000   139950.0         0        0.0
# 19452  3980300371  20140926T000000   142000.0         0        0.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 875           3064      4764     3.5           0     2  ...      7
# 1149           670     43377     1.0           0     0  ...      3
# ...

# %%
df[['grade', 'view', 'waterfront']]
# Out:
#        grade  view  waterfront
# 0          7     0           0
# 1          7     0           0
# 2          6     0           0
# 3          7     0           0
# 4          8     0           0
# ...      ...   ...         ...
# 21608      8     0           0
# 21609      8     0           0
# 21610      7     0           0
# 21611      8     0           0
# 21612      7     0           0
#
# [21613 rows x 3 columns]

# %%
type(df[['grade', 'view', 'waterfront']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# This is useful when we need to take some of the variables and perform analysis rather than all of them, since some might not be relevant.

# %% [markdown]
# ### .value_counts()

# %% [markdown]
# ```DataFrame.value_counts(subset=None, normalize=False, sort=True, ascending=False, dropna=True)```<br>
# Returns a Series containing counts of unique rows in the DataFrame.<br>
#
# **Parameters:**<br>
#
# subset: label or list of labels, optional<br>
# Columns to use when counting unique combinations.<br>

# %%
df.value_counts("bedrooms")
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# dtype: int64

# %% [markdown]
# normalize: bool, default False<br>
# Return proportions rather than frequencies.<br>

# %%
df.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df.bedrooms.value_counts(normalize = True)
# for example, 0.454541 = 9824/21613
# Out:
# 3     0.454541
# 4     0.318419
# 2     0.127701
# 5     0.074076
# 6     0.012585
# 1     0.009207
# 7     0.001758
# 0     0.000601
# 8     0.000601
# 9     0.000278
# 10    0.000139
# 11    0.000046
# 33    0.000046
# Name: bedrooms, dtype: float64

# %% [markdown]
# sort: bool, default: True<br>
# Sort by frequencies.<br>

# %%
df.bathrooms.value_counts(sort = False)
# Out:
# 1.00    3852
# 2.25    2047
# 3.00     753
# 2.00    1930
# 4.50     100
# 1.50    1446
# 2.50    5380
# 1.75    3048
# 2.75    1185
# 3.25     589
# 4.00     136
# 3.50     731
# 0.75      72
# 4.75      23
# 5.00      21
# 4.25      79
# 3.75     155
# 0.00      10
# 1.25       9
# 5.25      13
# 6.00       6
# 0.50       4
# 5.50      10
# 6.75       2
# 5.75       4
# 8.00       2
# 7.50       1
# 7.75       1
# 6.25       2
# 6.50       2
# Name: bathrooms, dtype: int64

# %% [markdown]
# ascending: bool, default False<br>
# Sort in ascending order.<br>

# %%
df.bedrooms.value_counts(ascending = True)
# The frequencies appear in ascending order
# Out:
# 11       1
# 33       1
# 10       3
# 9        6
# 0       13
# 8       13
# 7       38
# 1      199
# 6      272
# 5     1601
# 2     2760
# 4     6882
# 3     9824
# Name: bedrooms, dtype: int64

# %% [markdown]
# dropna: bool, default True<br>
# Don’t include counts of rows that contain NA values.<br>

# %%
# Our data does not include NA values as we see using .info()

# %% [markdown]
# ### .unique()

# %% [markdown]
# Return unique values based on a hash table.<br>
# Uniques are returned in order of appearance. This does NOT sort.<br>
# Significantly faster than numpy.unique for long enough sequences. Includes NA values.<br>
#
# Example:

# %%
pd.unique(list('hello there'))
# Out:
# array(['h', 'e', 'l', 'o', ' ', 't', 'r'], dtype=object)

# %% [markdown]
# ### .max() and .min()

# %% [markdown]
# ```DataFrame.max(axis=0, skipna=True, numeric_only=False, **kwargs)```
#
# **Parameters**<br>
# axis{index (0), columns (1)}<br>
# Axis for the function to be applied on. For Series this parameter is unused and defaults to 0.<br>
#
# For DataFrames, specifying axis=None will apply the aggregation across both axes.<br>
#
# skipna: bool, default True<br>
# Exclude NA/null values when computing the result.<br>
#
# numeric_only: bool, default False<br>
# Include only float, int, boolean columns. Not implemented for Series.<br>
#
# **kwargs<br>
# Additional keyword arguments to be passed to the function.

# %%
df.max(numeric_only = True)
# Out:
# id               9.900000e+09
# price            7.700000e+06
# bedrooms         3.300000e+01
# bathrooms        8.000000e+00
# sqft_living      1.354000e+04
# sqft_lot         1.651359e+06
# floors           3.500000e+00
# waterfront       1.000000e+00
# view             4.000000e+00
# condition        5.000000e+00
# grade            1.300000e+01
# sqft_above       9.410000e+03
# sqft_basement    4.820000e+03
# yr_built         2.015000e+03
# yr_renovated     2.015000e+03
# zipcode          9.819900e+04
# lat              4.777760e+01
# long            -1.213150e+02
# sqft_living15    6.210000e+03
# sqft_lot15       8.712000e+05
# dtype: float64

# %% [markdown]
# Same applies for ```min()``` and ```mean()``` except that they return the minimum and the average of the values over the requested axis respectively.

# %% [markdown]
# ### .nlargest(m) and .nsmallest(m)

# %% [markdown]
# ```DataFrame.nlargest(n, columns, keep='first')```<br>
# Returns the first n rows with the largest values in columns, in descending order. The columns that are not specified are returned as well, but not used for ordering.<br>
#
# **Parameters:**<br>
# n: int<br>
# Number of rows to return.<br>
#
# columns: label or list of labels<br>
# Column label(s) to order by.<br>
#
# keep{‘first’, ‘last’, ‘all’}, default ‘first’<br>
# Where there are duplicate values:<br>
#
# first : prioritize the first occurrence(s)<br>
# last : prioritize the last occurrence(s)<br>
# all : do not drop any duplicates, even it means selecting more than n items.
#
# Returns: DataFrame
#
# ```Note: Same goes for nsmallest except that it returns the first n rows with the smallest values in columns, in ascending order. ```

# %%
df.nlargest(3,'price')
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7060000.0         5       4.50
# 9254  9208900037  20140919T000000  6890000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
# 3914           2360      1940          2001    98004  47.6500 -122.214
# 9254           1030      2001             0    98039  47.6305 -122.240
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
# ...

# %%
df.nsmallest(10,'bedrooms','all')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 875    6306400140  20140612T000000  1100000.0         0       0.00
# 3119   3918400017  20150205T000000   380000.0         0       0.00
# 3467   1453602309  20140805T000000   288000.0         0       1.50
# 4868   6896300380  20141002T000000   228000.0         0       1.00
# 6994   2954400190  20140624T000000  1300000.0         0       0.00
# 8477   2569500210  20141117T000000   339950.0         0       2.50
# 8484   2310060040  20140925T000000   240000.0         0       2.50
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 12653  7849202299  20150218T000000   320000.0         0       2.50
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 18379  1222029077  20141029T000000   265000.0         0       0.75
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
# ...

# %% [markdown]
# # Part 3

# %% [markdown]
# ## Pandas DataFrame from a Dictionary

# %% [markdown]
# Syntax: ```pd.DataFrame.from_dict(dict, index, columns)```

# %%
course = {'Courses':['Python','SQL','Java','R'],
           'Fee':[200,500,450,150],
           'Duration':['30days','40days','60days','20days']}
newdf = pd.DataFrame.from_dict(course)
newdf
# Out:
#   Courses  Fee Duration
# 0  Python  200   30days
# 1     SQL  500   40days
# 2    Java  450   60days
# 3       R  150   20days

# %%
newdf = pd.DataFrame(course, index = [1,2,3,4])
newdf
# Out:
#   Courses  Fee Duration
# 1  Python  200   30days
# 2     SQL  500   40days
# 3    Java  450   60days
# 4       R  150   20days

# %%
newdf = pd.DataFrame(course, columns = ['Courses','Fee'])
newdf
# Out:
#   Courses  Fee
# 0  Python  200
# 1     SQL  500
# 2    Java  450
# 3       R  150

# %% [markdown]
# # Part 4

# %% [markdown]
# Here are the data types and their usages in pandas:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df['date'].dtypes
# Out:
# dtype('O')

# %%
df['lat'].dtypes
# Out:
# dtype('float64')

# %%
df.sqft_living.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### Changing from one data type to another

# %% [markdown]
# We use ```astype()``` for that purpose.

# %%
df['view'].astype('bool')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: view, Length: 21613, dtype: bool

# %%
df[df['view'] == True] # True and 1 are the same
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 282    7424700045  20150513T000000  2050000.0         5       3.00
# 394    1923000030  20140728T000000  1120000.0         4       2.50
# 472    8820902200  20141113T000000  1200000.0         4       2.75
# 489    5423010350  20150210T000000  1280000.0         5       2.50
# 491    2475200140  20150205T000000   370000.0         3       2.00
# ...           ...              ...        ...       ...        ...
# 21040  6447300365  20141113T000000  2900000.0         5       4.00
# 21082  8562900430  20140718T000000   800000.0         4       2.50
# 21310  2154970020  20140703T000000  2350000.0         4       4.25
# 21395  3879900754  20140915T000000   779000.0         3       2.50
# 21425  8924100308  20150203T000000  1050000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 282           3830      8480     2.0           0     1  ...      9
# ...
